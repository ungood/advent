# %% [markdown]
# # Day 11 - Monkey in the Middle
#
# ## Data

# %%
example_data = """
Monkey 0:
  Starting items: 79, 98
  Operation: new = old * 19
  Test: divisible by 23
    If true: throw to monkey 2
    If false: throw to monkey 3

Monkey 1:
  Starting items: 54, 65, 75, 74
  Operation: new = old + 6
  Test: divisible by 19
    If true: throw to monkey 2
    If false: throw to monkey 0

Monkey 2:
  Starting items: 79, 60, 97
  Operation: new = old * old
  Test: divisible by 13
    If true: throw to monkey 1
    If false: throw to monkey 3

Monkey 3:
  Starting items: 74
  Operation: new = old + 3
  Test: divisible by 17
    If true: throw to monkey 0
    If false: throw to monkey 1
""".strip()

print(example_data)
# Out:
# Monkey 0:
#   Starting items: 79, 98
#   Operation: new = old * 19
#   Test: divisible by 23
#     If true: throw to monkey 2
#     If false: throw to monkey 3
#
# Monkey 1:
#   Starting items: 54, 65, 75, 74
#   Operation: new = old + 6
#   Test: divisible by 19
#     If true: throw to monkey 2
#     If false: throw to monkey 0
#
# Monkey 2:
#   Starting items: 79, 60, 97
#   Operation: new = old * old
#   Test: divisible by 13
#     If true: throw to monkey 1
#     If false: throw to monkey 3
#
# Monkey 3:
#   Starting items: 74
#   Operation: new = old + 3
#   Test: divisible by 17
#     If true: throw to monkey 0
#     If false: throw to monkey 1

# %%
import aocd
raw_data = aocd.get_data(year=2022, day=11)
print(raw_data)
# Out:
# Monkey 0:
#   Starting items: 89, 73, 66, 57, 64, 80
#   Operation: new = old * 3
#   Test: divisible by 13
#     If true: throw to monkey 6
#     If false: throw to monkey 2
#
# Monkey 1:
#   Starting items: 83, 78, 81, 55, 81, 59, 69
#   Operation: new = old + 1
#   Test: divisible by 3
#     If true: throw to monkey 7
#     If false: throw to monkey 4
#
# Monkey 2:
#   Starting items: 76, 91, 58, 85
#   Operation: new = old * 13
#   Test: divisible by 7
#     If true: throw to monkey 1
#     If false: throw to monkey 4
#
# Monkey 3:
#   Starting items: 71, 72, 74, 76, 68
#   Operation: new = old * old
#   Test: divisible by 2
#     If true: throw to monkey 6
#     If false: throw to monkey 0
#
# Monkey 4:
#   Starting items: 98, 85, 84
#   Operation: new = old + 7
#   Test: divisible by 19
#     If true: throw to monkey 5
#     If false: throw to monkey 7
#
# Monkey 5:
#   Starting items: 78
#   Operation: new = old + 8
#   Test: divisible by 5
#     If true: throw to monkey 3
#     If false: throw to monkey 0
#
# Monkey 6:
#   Starting items: 86, 70, 60, 88, 88, 78, 74, 83
#   Operation: new = old + 4
#   Test: divisible by 11
#     If true: throw to monkey 1
#     If false: throw to monkey 2
#
# Monkey 7:
#   Starting items: 81, 58
#   Operation: new = old + 5
#   Test: divisible by 17
#     If true: throw to monkey 3
#     If false: throw to monkey 5

# %%
from dataclasses import dataclass
from typing import Callable

@dataclass
class MonkeyBusinessRules:
    debug: bool
    divide_worry_level: bool
    modulus: int

        
@dataclass
class ItemToss(object):
    """Represents one monkey throwing an item to another monkey."""
    item: int
    target: int
            

@dataclass
class Monkey(object):
    number: int
    items: list[int]
    operation: Callable[[int], int]
    throw_to: Callable[[int], int]
    items_inspected: int = 0    
        
    def __repr__(self):
        return f" Monkey {self.number} Has items {self.items}"

    def catch_item(self, item):
        self.items.append(item)
    
    def inspect_item(self, rules):
        """Changes the worry level of the first item and determines which monkey to toss it to."""
        self.items_inspected += 1
        
        inspectee = self.items.pop(0)
        
        if rules.debug:
            print(f"Monkey {self.number} is inspecting item with worry level {inspectee}")

        inspectee = self.operation(inspectee)
        if rules.divide_worry_level:
            inspectee //= 3
        else:
            inspectee %= rules.modulus
            
        target = self.throw_to(inspectee)
        
        if rules.debug:
            print(f"  Monkey {self.number} throws item {inspectee} to monkey {target}!")
        
        return ItemToss(inspectee, target)
    
    def play_turn(self, rules):
        while len(self.items) > 0:
            yield self.inspect_item(rules)

# %% [markdown]
# ## Parsing

# %%
import pyparsing as pp

integer = pp.Word(pp.nums)
        
@integer.set_parse_action
def parse_integer(tokens):
    return int(tokens[0])

identifier = pp.Word(pp.alphas)
term = identifier | integer
@term.set_parse_action
def parse_term(tokens):
    """Tokens is either an integer or a name of a  variable to lookup"""
    def resolve_identifier(identifiers):
        if type(tokens[0]) == int:
            return tokens[0]
        else:
            return identifiers[tokens[0]]
    return resolve_identifier


operators = {
    '+': lambda left, right: left + right,
    '-': lambda left, right: left - right,
    '*': lambda left, right: left * right,
    '/': lambda left, right: left / right
}

operator = pp.one_of("+ - * /")
@operator.set_parse_action
def parse_operator(tokens):
    op = tokens[0]
    return operators[op]


binary_expression = term + operator + term
@binary_expression.set_parse_action
def binary_expression(tokens):
    def calculate(identifiers):
        left = tokens[0](identifiers)
        op = tokens[1]
        right = tokens[2](identifiers)
        return op(left, right)

    return calculate

test_binary_expression = binary_expression.parse_string("foo * bar")[0]
assert test_binary_expression({
    "foo": 3,
    "bar": 5
}) == 15

# %%
monkey_number = pp.Suppress("Monkey") + integer + pp.Suppress(":")
monkey_number.run_tests("""
Monkey 3:
Monkey 5:
Monkey18:
""")

integer_list = pp.delimited_list(integer)
starting_items = pp.Suppress("Starting items:") + integer_list

@starting_items.set_parse_action
def parse_starting_items(tokens):
    return tuple(tokens)

starting_items.run_tests("""
Starting items: 1, 2, 3
Starting items: 4,5
""")


operation = pp.Suppress("Operation: new = ") + binary_expression

@operation.set_parse_action
def parse_operation(tokens):
    """
    Return a function that given the old worry level, returns the new worry level.
    """
    def operation(old):
        return tokens[0]({"old": old})
    return operation

test_operation = operation.parse_string("Operation: new = old + old")[0]

assert test_operation(5) == 10

condition = pp.Suppress("Test: divisible by") + integer
true_case = pp.Suppress("If true: throw to monkey") + integer
false_case = pp.Suppress("If false: throw to monkey") + integer
throw_to = condition + true_case + false_case

@throw_to.set_parse_action
def parse_throw_to(tokens):
    """
    Returns a function that takes the worry level and returns the monkey to throw the item to.
    tokens[0] = condition to check worry level against
    tokens[1] = true case
    tokens[2] = false case
    """
    def throw_to(worry_level):
        if worry_level % tokens[0] == 0:
            return tokens[1]
        return tokens[2]
    
    throw_to.modulus = tokens[0]
    return throw_to

test_throw_to = throw_to.parse_string("""
Test: divisible by 11
    If true: throw to monkey 1
    If false: throw to monkey 2
""")[0]

assert test_throw_to(22) == 1
assert test_throw_to(1) == 2

monkey = monkey_number + starting_items + operation + throw_to

@monkey.set_parse_action
def parse_monkey(tokens):
    return Monkey(
        number = tokens[0],
        items = list(tokens[1]),
        operation = tokens[2],
        throw_to = tokens[3]
    )

monkey_language = pp.ZeroOrMore(monkey)


def parse(data):
    return monkey_language.parse_string(data).as_list()

example_monkeys = parse(example_data)

real_monkeys = parse(raw_data)

example_monkeys
# Out:
# Monkey 3:
# [3]
#
# Monkey 5:
# [5]
#
# Monkey18:
# [18]
#
# Starting items: 1, 2, 3
# [(1, 2, 3)]
#
# Starting items: 4,5
# [(4, 5)]
# [ Monkey 0 Has items [79, 98],
#   Monkey 1 Has items [54, 65, 75, 74],
#   Monkey 2 Has items [79, 60, 97],
#   Monkey 3 Has items [74]]

# %% [markdown]
# ## Part 1

# %%
def play_round(monkeys, rules):
    for monkey in monkeys:
        for toss in monkey.play_turn(rules):
            catcher = monkeys[toss.target]
            catcher.catch_item(toss.item)


def calculate_monkey_business(monkeys, num_rounds = 20, debug = False, divide_worry_level = True):
    """
    Run num_rounds of Monkey in the Middle, return the product of the number of items inspected by
    the 2 most active monkeys.
    """
    
    # Calculate the modulus to adjust the worry level by calculating a multiple of all
    # monkey's modulus value.
    modulus = 1
    for monkey in monkeys:
        modulus *= monkey.throw_to.modulus
    
    print(f"Adjust monkey business by {modulus}")
    
    rules = MonkeyBusinessRules(debug, divide_worry_level, modulus = modulus)
    
    
    for i in range(num_rounds):
        play_round(monkeys, rules)
        if i % 1000 == 0:
            print(f"Ran {i} rounds")
        
    monkeys.sort(key = lambda monkey: monkey.items_inspected, reverse = True)
    
    print(f"The most active monkey is {monkeys[0]}, and then monkey{monkeys[1]}")
    
    return monkeys[0].items_inspected * monkeys[1].items_inspected

assert calculate_monkey_business(example_monkeys, debug = True) == 10605
# Out:
# Adjust monkey business by 96577
# Monkey 0 is inspecting item with worry level 79
#   Monkey 0 throws item 500 to monkey 3!
# Monkey 0 is inspecting item with worry level 98
#   Monkey 0 throws item 620 to monkey 3!
# Monkey 1 is inspecting item with worry level 54
#   Monkey 1 throws item 20 to monkey 0!
# Monkey 1 is inspecting item with worry level 65
#   Monkey 1 throws item 23 to monkey 0!
# Monkey 1 is inspecting item with worry level 75
#   Monkey 1 throws item 27 to monkey 0!
# Monkey 1 is inspecting item with worry level 74
#   Monkey 1 throws item 26 to monkey 0!
# Monkey 2 is inspecting item with worry level 79
#   Monkey 2 throws item 2080 to monkey 1!
# Monkey 2 is inspecting item with worry level 60
#   Monkey 2 throws item 1200 to monkey 3!
# Monkey 2 is inspecting item with worry level 97
#   Monkey 2 throws item 3136 to monkey 3!
# Monkey 3 is inspecting item with worry level 74
#   Monkey 3 throws item 25 to monkey 1!
# Monkey 3 is inspecting item with worry level 500
#   Monkey 3 throws item 167 to monkey 1!
# Monkey 3 is inspecting item with worry level 620
#   Monkey 3 throws item 207 to monkey 1!
# Monkey 3 is inspecting item with worry level 1200
#   Monkey 3 throws item 401 to monkey 1!
# Monkey 3 is inspecting item with worry level 3136
#   Monkey 3 throws item 1046 to monkey 1!
# Ran 0 rounds
# Monkey 0 is inspecting item with worry level 20
#   Monkey 0 throws item 126 to monkey 3!
# Monkey 0 is inspecting item with worry level 23
#   Monkey 0 throws item 145 to monkey 3!
# Monkey 0 is inspecting item with worry level 27
#   Monkey 0 throws item 171 to monkey 3!
# Monkey 0 is inspecting item with worry level 26
#   Monkey 0 throws item 164 to monkey 3!
# Monkey 1 is inspecting item with worry level 2080
#   Monkey 1 throws item 695 to monkey 0!
# Monkey 1 is inspecting item with worry level 25
#   Monkey 1 throws item 10 to monkey 0!
# Monkey 1 is inspecting item with worry level 167
#   Monkey 1 throws item 57 to monkey 2!
# Monkey 1 is inspecting item with worry level 207
#   Monkey 1 throws item 71 to monkey 0!
# Monkey 1 is inspecting item with worry level 401
#   Monkey 1 throws item 135 to monkey 0!
# Monkey 1 is inspecting item with worry level 1046
#   Monkey 1 throws item 350 to monkey 0!
# Monkey 2 is inspecting item with worry level 57
#   Monkey 2 throws item 1083 to monkey 3!
# Monkey 3 is inspecting item with worry level 126
#   Monkey 3 throws item 43 to monkey 1!
# Monkey 3 is inspecting item with worry level 145
#   Monkey 3 throws item 49 to monkey 1!
# Monkey 3 is inspecting item with worry level 171
#   Monkey 3 throws item 58 to monkey 1!
# Monkey 3 is inspecting item with worry level 164
#   Monkey 3 throws item 55 to monkey 1!
# Monkey 3 is inspecting item with worry level 1083
#   Monkey 3 throws item 362 to monkey 1!
# Monkey 0 is inspecting item with worry level 695
#   Monkey 0 throws item 4401 to monkey 3!
# Monkey 0 is inspecting item with worry level 10
#   Monkey 0 throws item 63 to monkey 3!
# Monkey 0 is inspecting item with worry level 71
#   Monkey 0 throws item 449 to monkey 3!
# Monkey 0 is inspecting item with worry level 135
#   Monkey 0 throws item 855 to monkey 3!
# Monkey 0 is inspecting item with worry level 350
#   Monkey 0 throws item 2216 to monkey 3!
# Monkey 1 is inspecting item with worry level 43
#   Monkey 1 throws item 16 to monkey 0!
# Monkey 1 is inspecting item with worry level 49
#   Monkey 1 throws item 18 to monkey 0!
# Monkey 1 is inspecting item with worry level 58
#   Monkey 1 throws item 21 to monkey 0!
# Monkey 1 is inspecting item with worry level 55
#   Monkey 1 throws item 20 to monkey 0!
# Monkey 1 is inspecting item with worry level 362
#   Monkey 1 throws item 122 to monkey 0!
# Monkey 3 is inspecting item with worry level 4401
#   Monkey 3 throws item 1468 to monkey 1!
# Monkey 3 is inspecting item with worry level 63
#   Monkey 3 throws item 22 to monkey 1!
# Monkey 3 is inspecting item with worry level 449
#   Monkey 3 throws item 150 to monkey 1!
# Monkey 3 is inspecting item with worry level 855
#   Monkey 3 throws item 286 to monkey 1!
# Monkey 3 is inspecting item with worry level 2216
#   Monkey 3 throws item 739 to monkey 1!
# Monkey 0 is inspecting item with worry level 16
#   Monkey 0 throws item 101 to monkey 3!
# Monkey 0 is inspecting item with worry level 18
#   Monkey 0 throws item 114 to monkey 3!
# Monkey 0 is inspecting item with worry level 21
#   Monkey 0 throws item 133 to monkey 3!
# Monkey 0 is inspecting item with worry level 20
#   Monkey 0 throws item 126 to monkey 3!
# Monkey 0 is inspecting item with worry level 122
#   Monkey 0 throws item 772 to monkey 3!
# Monkey 1 is inspecting item with worry level 1468
#   Monkey 1 throws item 491 to monkey 0!
# Monkey 1 is inspecting item with worry level 22
#   Monkey 1 throws item 9 to monkey 0!
# Monkey 1 is inspecting item with worry level 150
#   Monkey 1 throws item 52 to monkey 0!
# Monkey 1 is inspecting item with worry level 286
#   Monkey 1 throws item 97 to monkey 0!
# Monkey 1 is inspecting item with worry level 739
#   Monkey 1 throws item 248 to monkey 0!
# Monkey 3 is inspecting item with worry level 101
#   Monkey 3 throws item 34 to monkey 0!
# Monkey 3 is inspecting item with worry level 114
#   Monkey 3 throws item 39 to monkey 1!
# Monkey 3 is inspecting item with worry level 133
#   Monkey 3 throws item 45 to monkey 1!
# Monkey 3 is inspecting item with worry level 126
#   Monkey 3 throws item 43 to monkey 1!
# Monkey 3 is inspecting item with worry level 772
#   Monkey 3 throws item 258 to monkey 1!
# Monkey 0 is inspecting item with worry level 491
#   Monkey 0 throws item 3109 to monkey 3!
# Monkey 0 is inspecting item with worry level 9
#   Monkey 0 throws item 57 to monkey 3!
# Monkey 0 is inspecting item with worry level 52
#   Monkey 0 throws item 329 to monkey 3!
# Monkey 0 is inspecting item with worry level 97
#   Monkey 0 throws item 614 to monkey 3!
# Monkey 0 is inspecting item with worry level 248
#   Monkey 0 throws item 1570 to monkey 3!
# Monkey 0 is inspecting item with worry level 34
#   Monkey 0 throws item 215 to monkey 3!
# Monkey 1 is inspecting item with worry level 39
#   Monkey 1 throws item 15 to monkey 0!
# Monkey 1 is inspecting item with worry level 45
#   Monkey 1 throws item 17 to monkey 0!
# Monkey 1 is inspecting item with worry level 43
#   Monkey 1 throws item 16 to monkey 0!
# Monkey 1 is inspecting item with worry level 258
#   Monkey 1 throws item 88 to monkey 0!
# Monkey 3 is inspecting item with worry level 3109
#   Monkey 3 throws item 1037 to monkey 0!
# Monkey 3 is inspecting item with worry level 57
#   Monkey 3 throws item 20 to monkey 1!
# Monkey 3 is inspecting item with worry level 329
#   Monkey 3 throws item 110 to monkey 1!
# Monkey 3 is inspecting item with worry level 614
#   Monkey 3 throws item 205 to monkey 1!
# Monkey 3 is inspecting item with worry level 1570
#   Monkey 3 throws item 524 to monkey 1!
# Monkey 3 is inspecting item with worry level 215
#   Monkey 3 throws item 72 to monkey 1!
# Monkey 0 is inspecting item with worry level 15
#   Monkey 0 throws item 95 to monkey 3!
# Monkey 0 is inspecting item with worry level 17
#   Monkey 0 throws item 107 to monkey 3!
# Monkey 0 is inspecting item with worry level 16
#   Monkey 0 throws item 101 to monkey 3!
# Monkey 0 is inspecting item with worry level 88
#   Monkey 0 throws item 557 to monkey 3!
# Monkey 0 is inspecting item with worry level 1037
#   Monkey 0 throws item 6567 to monkey 3!
# Monkey 1 is inspecting item with worry level 20
#   Monkey 1 throws item 8 to monkey 0!
# Monkey 1 is inspecting item with worry level 110
#   Monkey 1 throws item 38 to monkey 2!
# Monkey 1 is inspecting item with worry level 205
#   Monkey 1 throws item 70 to monkey 0!
# Monkey 1 is inspecting item with worry level 524
#   Monkey 1 throws item 176 to monkey 0!
# Monkey 1 is inspecting item with worry level 72
#   Monkey 1 throws item 26 to monkey 0!
# Monkey 2 is inspecting item with worry level 38
#   Monkey 2 throws item 481 to monkey 1!
# Monkey 3 is inspecting item with worry level 95
#   Monkey 3 throws item 32 to monkey 1!
# Monkey 3 is inspecting item with worry level 107
#   Monkey 3 throws item 36 to monkey 1!
# Monkey 3 is inspecting item with worry level 101
#   Monkey 3 throws item 34 to monkey 0!
# Monkey 3 is inspecting item with worry level 557
#   Monkey 3 throws item 186 to monkey 1!
# Monkey 3 is inspecting item with worry level 6567
#   Monkey 3 throws item 2190 to monkey 1!
# Monkey 0 is inspecting item with worry level 8
#   Monkey 0 throws item 50 to monkey 3!
# Monkey 0 is inspecting item with worry level 70
#   Monkey 0 throws item 443 to monkey 3!
# Monkey 0 is inspecting item with worry level 176
#   Monkey 0 throws item 1114 to monkey 3!
# Monkey 0 is inspecting item with worry level 26
#   Monkey 0 throws item 164 to monkey 3!
# Monkey 0 is inspecting item with worry level 34
#   Monkey 0 throws item 215 to monkey 3!
# Monkey 1 is inspecting item with worry level 481
#   Monkey 1 throws item 162 to monkey 0!
# Monkey 1 is inspecting item with worry level 32
#   Monkey 1 throws item 12 to monkey 0!
# Monkey 1 is inspecting item with worry level 36
#   Monkey 1 throws item 14 to monkey 0!
# Monkey 1 is inspecting item with worry level 186
#   Monkey 1 throws item 64 to monkey 0!
# Monkey 1 is inspecting item with worry level 2190
#   Monkey 1 throws item 732 to monkey 0!
# Monkey 3 is inspecting item with worry level 50
#   Monkey 3 throws item 17 to monkey 0!
# Monkey 3 is inspecting item with worry level 443
#   Monkey 3 throws item 148 to monkey 1!
# Monkey 3 is inspecting item with worry level 1114
#   Monkey 3 throws item 372 to monkey 1!
# Monkey 3 is inspecting item with worry level 164
#   Monkey 3 throws item 55 to monkey 1!
# Monkey 3 is inspecting item with worry level 215
#   Monkey 3 throws item 72 to monkey 1!
# Monkey 0 is inspecting item with worry level 162
#   Monkey 0 throws item 1026 to monkey 3!
# Monkey 0 is inspecting item with worry level 12
#   Monkey 0 throws item 76 to monkey 3!
# Monkey 0 is inspecting item with worry level 14
#   Monkey 0 throws item 88 to monkey 3!
# Monkey 0 is inspecting item with worry level 64
#   Monkey 0 throws item 405 to monkey 3!
# Monkey 0 is inspecting item with worry level 732
#   Monkey 0 throws item 4636 to monkey 3!
# Monkey 0 is inspecting item with worry level 17
#   Monkey 0 throws item 107 to monkey 3!
# Monkey 1 is inspecting item with worry level 148
#   Monkey 1 throws item 51 to monkey 0!
# Monkey 1 is inspecting item with worry level 372
#   Monkey 1 throws item 126 to monkey 0!
# Monkey 1 is inspecting item with worry level 55
#   Monkey 1 throws item 20 to monkey 0!
# Monkey 1 is inspecting item with worry level 72
#   Monkey 1 throws item 26 to monkey 0!
# Monkey 3 is inspecting item with worry level 1026
#   Monkey 3 throws item 343 to monkey 1!
# Monkey 3 is inspecting item with worry level 76
#   Monkey 3 throws item 26 to monkey 1!
# Monkey 3 is inspecting item with worry level 88
#   Monkey 3 throws item 30 to monkey 1!
# Monkey 3 is inspecting item with worry level 405
#   Monkey 3 throws item 136 to monkey 0!
# Monkey 3 is inspecting item with worry level 4636
#   Monkey 3 throws item 1546 to monkey 1!
# Monkey 3 is inspecting item with worry level 107
#   Monkey 3 throws item 36 to monkey 1!
# Monkey 0 is inspecting item with worry level 51
#   Monkey 0 throws item 323 to monkey 3!
# Monkey 0 is inspecting item with worry level 126
#   Monkey 0 throws item 798 to monkey 3!
# Monkey 0 is inspecting item with worry level 20
#   Monkey 0 throws item 126 to monkey 3!
# Monkey 0 is inspecting item with worry level 26
#   Monkey 0 throws item 164 to monkey 3!
# Monkey 0 is inspecting item with worry level 136
#   Monkey 0 throws item 861 to monkey 3!
# Monkey 1 is inspecting item with worry level 343
#   Monkey 1 throws item 116 to monkey 0!
# Monkey 1 is inspecting item with worry level 26
#   Monkey 1 throws item 10 to monkey 0!
# Monkey 1 is inspecting item with worry level 30
#   Monkey 1 throws item 12 to monkey 0!
# Monkey 1 is inspecting item with worry level 1546
#   Monkey 1 throws item 517 to monkey 0!
# Monkey 1 is inspecting item with worry level 36
#   Monkey 1 throws item 14 to monkey 0!
# Monkey 3 is inspecting item with worry level 323
#   Monkey 3 throws item 108 to monkey 1!
# Monkey 3 is inspecting item with worry level 798
#   Monkey 3 throws item 267 to monkey 1!
# Monkey 3 is inspecting item with worry level 126
#   Monkey 3 throws item 43 to monkey 1!
# Monkey 3 is inspecting item with worry level 164
#   Monkey 3 throws item 55 to monkey 1!
# Monkey 3 is inspecting item with worry level 861
#   Monkey 3 throws item 288 to monkey 1!
# Monkey 0 is inspecting item with worry level 116
#   Monkey 0 throws item 734 to monkey 3!
# Monkey 0 is inspecting item with worry level 10
#   Monkey 0 throws item 63 to monkey 3!
# Monkey 0 is inspecting item with worry level 12
#   Monkey 0 throws item 76 to monkey 3!
# Monkey 0 is inspecting item with worry level 517
#   Monkey 0 throws item 3274 to monkey 3!
# Monkey 0 is inspecting item with worry level 14
#   Monkey 0 throws item 88 to monkey 3!
# Monkey 1 is inspecting item with worry level 108
#   Monkey 1 throws item 38 to monkey 2!
# Monkey 1 is inspecting item with worry level 267
#   Monkey 1 throws item 91 to monkey 0!
# Monkey 1 is inspecting item with worry level 43
#   Monkey 1 throws item 16 to monkey 0!
# Monkey 1 is inspecting item with worry level 55
#   Monkey 1 throws item 20 to monkey 0!
# Monkey 1 is inspecting item with worry level 288
#   Monkey 1 throws item 98 to monkey 0!
# Monkey 2 is inspecting item with worry level 38
#   Monkey 2 throws item 481 to monkey 1!
# Monkey 3 is inspecting item with worry level 734
#   Monkey 3 throws item 245 to monkey 1!
# Monkey 3 is inspecting item with worry level 63
#   Monkey 3 throws item 22 to monkey 1!
# Monkey 3 is inspecting item with worry level 76
#   Monkey 3 throws item 26 to monkey 1!
# Monkey 3 is inspecting item with worry level 3274
#   Monkey 3 throws item 1092 to monkey 1!
# Monkey 3 is inspecting item with worry level 88
#   Monkey 3 throws item 30 to monkey 1!
# Monkey 0 is inspecting item with worry level 91
#   Monkey 0 throws item 576 to monkey 3!
# Monkey 0 is inspecting item with worry level 16
#   Monkey 0 throws item 101 to monkey 3!
# Monkey 0 is inspecting item with worry level 20
#   Monkey 0 throws item 126 to monkey 3!
# Monkey 0 is inspecting item with worry level 98
#   Monkey 0 throws item 620 to monkey 3!
# Monkey 1 is inspecting item with worry level 481
#   Monkey 1 throws item 162 to monkey 0!
# Monkey 1 is inspecting item with worry level 245
#   Monkey 1 throws item 83 to monkey 0!
# Monkey 1 is inspecting item with worry level 22
#   Monkey 1 throws item 9 to monkey 0!
# Monkey 1 is inspecting item with worry level 26
#   Monkey 1 throws item 10 to monkey 0!
# Monkey 1 is inspecting item with worry level 1092
#   Monkey 1 throws item 366 to monkey 0!
# Monkey 1 is inspecting item with worry level 30
#   Monkey 1 throws item 12 to monkey 0!
# Monkey 3 is inspecting item with worry level 576
#   Monkey 3 throws item 193 to monkey 1!
# Monkey 3 is inspecting item with worry level 101
#   Monkey 3 throws item 34 to monkey 0!
# Monkey 3 is inspecting item with worry level 126
#   Monkey 3 throws item 43 to monkey 1!
# Monkey 3 is inspecting item with worry level 620
#   Monkey 3 throws item 207 to monkey 1!
# Monkey 0 is inspecting item with worry level 162
#   Monkey 0 throws item 1026 to monkey 3!
# Monkey 0 is inspecting item with worry level 83
#   Monkey 0 throws item 525 to monkey 3!
# Monkey 0 is inspecting item with worry level 9
#   Monkey 0 throws item 57 to monkey 3!
# Monkey 0 is inspecting item with worry level 10
#   Monkey 0 throws item 63 to monkey 3!
# Monkey 0 is inspecting item with worry level 366
#   Monkey 0 throws item 2318 to monkey 3!
# Monkey 0 is inspecting item with worry level 12
#   Monkey 0 throws item 76 to monkey 3!
# Monkey 0 is inspecting item with worry level 34
#   Monkey 0 throws item 215 to monkey 3!
# Monkey 1 is inspecting item with worry level 193
#   Monkey 1 throws item 66 to monkey 0!
# Monkey 1 is inspecting item with worry level 43
#   Monkey 1 throws item 16 to monkey 0!
# Monkey 1 is inspecting item with worry level 207
#   Monkey 1 throws item 71 to monkey 0!
# Monkey 3 is inspecting item with worry level 1026
#   Monkey 3 throws item 343 to monkey 1!
# Monkey 3 is inspecting item with worry level 525
#   Monkey 3 throws item 176 to monkey 1!
# Monkey 3 is inspecting item with worry level 57
#   Monkey 3 throws item 20 to monkey 1!
# Monkey 3 is inspecting item with worry level 63
#   Monkey 3 throws item 22 to monkey 1!
# Monkey 3 is inspecting item with worry level 2318
#   Monkey 3 throws item 773 to monkey 1!
# Monkey 3 is inspecting item with worry level 76
#   Monkey 3 throws item 26 to monkey 1!
# Monkey 3 is inspecting item with worry level 215
#   Monkey 3 throws item 72 to monkey 1!
# Monkey 0 is inspecting item with worry level 66
#   Monkey 0 throws item 418 to monkey 3!
# Monkey 0 is inspecting item with worry level 16
#   Monkey 0 throws item 101 to monkey 3!
# Monkey 0 is inspecting item with worry level 71
#   Monkey 0 throws item 449 to monkey 3!
# Monkey 1 is inspecting item with worry level 343
#   Monkey 1 throws item 116 to monkey 0!
# Monkey 1 is inspecting item with worry level 176
#   Monkey 1 throws item 60 to monkey 0!
# Monkey 1 is inspecting item with worry level 20
#   Monkey 1 throws item 8 to monkey 0!
# Monkey 1 is inspecting item with worry level 22
#   Monkey 1 throws item 9 to monkey 0!
# Monkey 1 is inspecting item with worry level 773
#   Monkey 1 throws item 259 to monkey 0!
# Monkey 1 is inspecting item with worry level 26
#   Monkey 1 throws item 10 to monkey 0!
# Monkey 1 is inspecting item with worry level 72
#   Monkey 1 throws item 26 to monkey 0!
# Monkey 3 is inspecting item with worry level 418
#   Monkey 3 throws item 140 to monkey 1!
# Monkey 3 is inspecting item with worry level 101
#   Monkey 3 throws item 34 to monkey 0!
# Monkey 3 is inspecting item with worry level 449
#   Monkey 3 throws item 150 to monkey 1!
# Monkey 0 is inspecting item with worry level 116
#   Monkey 0 throws item 734 to monkey 3!
# Monkey 0 is inspecting item with worry level 60
#   Monkey 0 throws item 380 to monkey 3!
# Monkey 0 is inspecting item with worry level 8
#   Monkey 0 throws item 50 to monkey 3!
# Monkey 0 is inspecting item with worry level 9
#   Monkey 0 throws item 57 to monkey 3!
# Monkey 0 is inspecting item with worry level 259
#   Monkey 0 throws item 1640 to monkey 3!
# Monkey 0 is inspecting item with worry level 10
#   Monkey 0 throws item 63 to monkey 3!
# Monkey 0 is inspecting item with worry level 26
#   Monkey 0 throws item 164 to monkey 3!
# Monkey 0 is inspecting item with worry level 34
#   Monkey 0 throws item 215 to monkey 3!
# Monkey 1 is inspecting item with worry level 140
#   Monkey 1 throws item 48 to monkey 0!
# Monkey 1 is inspecting item with worry level 150
#   Monkey 1 throws item 52 to monkey 0!
# Monkey 3 is inspecting item with worry level 734
#   Monkey 3 throws item 245 to monkey 1!
# Monkey 3 is inspecting item with worry level 380
#   Monkey 3 throws item 127 to monkey 1!
# Monkey 3 is inspecting item with worry level 50
#   Monkey 3 throws item 17 to monkey 0!
# Monkey 3 is inspecting item with worry level 57
#   Monkey 3 throws item 20 to monkey 1!
# Monkey 3 is inspecting item with worry level 1640
#   Monkey 3 throws item 547 to monkey 1!
# Monkey 3 is inspecting item with worry level 63
#   Monkey 3 throws item 22 to monkey 1!
# Monkey 3 is inspecting item with worry level 164
#   Monkey 3 throws item 55 to monkey 1!
# Monkey 3 is inspecting item with worry level 215
#   Monkey 3 throws item 72 to monkey 1!
# Monkey 0 is inspecting item with worry level 48
#   Monkey 0 throws item 304 to monkey 3!
# Monkey 0 is inspecting item with worry level 52
#   Monkey 0 throws item 329 to monkey 3!
# Monkey 0 is inspecting item with worry level 17
#   Monkey 0 throws item 107 to monkey 3!
# Monkey 1 is inspecting item with worry level 245
#   Monkey 1 throws item 83 to monkey 0!
# Monkey 1 is inspecting item with worry level 127
#   Monkey 1 throws item 44 to monkey 0!
# Monkey 1 is inspecting item with worry level 20
#   Monkey 1 throws item 8 to monkey 0!
# Monkey 1 is inspecting item with worry level 547
#   Monkey 1 throws item 184 to monkey 0!
# Monkey 1 is inspecting item with worry level 22
#   Monkey 1 throws item 9 to monkey 0!
# Monkey 1 is inspecting item with worry level 55
#   Monkey 1 throws item 20 to monkey 0!
# Monkey 1 is inspecting item with worry level 72
#   Monkey 1 throws item 26 to monkey 0!
# Monkey 3 is inspecting item with worry level 304
#   Monkey 3 throws item 102 to monkey 0!
# Monkey 3 is inspecting item with worry level 329
#   Monkey 3 throws item 110 to monkey 1!
# Monkey 3 is inspecting item with worry level 107
#   Monkey 3 throws item 36 to monkey 1!
# Monkey 0 is inspecting item with worry level 83
#   Monkey 0 throws item 525 to monkey 3!
# Monkey 0 is inspecting item with worry level 44
#   Monkey 0 throws item 278 to monkey 3!
# Monkey 0 is inspecting item with worry level 8
#   Monkey 0 throws item 50 to monkey 3!
# Monkey 0 is inspecting item with worry level 184
#   Monkey 0 throws item 1165 to monkey 3!
# Monkey 0 is inspecting item with worry level 9
#   Monkey 0 throws item 57 to monkey 3!
# Monkey 0 is inspecting item with worry level 20
#   Monkey 0 throws item 126 to monkey 3!
# Monkey 0 is inspecting item with worry level 26
#   Monkey 0 throws item 164 to monkey 3!
# Monkey 0 is inspecting item with worry level 102
#   Monkey 0 throws item 646 to monkey 3!
# Monkey 1 is inspecting item with worry level 110
#   Monkey 1 throws item 38 to monkey 2!
# Monkey 1 is inspecting item with worry level 36
#   Monkey 1 throws item 14 to monkey 0!
# Monkey 2 is inspecting item with worry level 38
#   Monkey 2 throws item 481 to monkey 1!
# Monkey 3 is inspecting item with worry level 525
#   Monkey 3 throws item 176 to monkey 1!
# Monkey 3 is inspecting item with worry level 278
#   Monkey 3 throws item 93 to monkey 1!
# Monkey 3 is inspecting item with worry level 50
#   Monkey 3 throws item 17 to monkey 0!
# Monkey 3 is inspecting item with worry level 1165
#   Monkey 3 throws item 389 to monkey 1!
# Monkey 3 is inspecting item with worry level 57
#   Monkey 3 throws item 20 to monkey 1!
# Monkey 3 is inspecting item with worry level 126
#   Monkey 3 throws item 43 to monkey 1!
# Monkey 3 is inspecting item with worry level 164
#   Monkey 3 throws item 55 to monkey 1!
# Monkey 3 is inspecting item with worry level 646
#   Monkey 3 throws item 216 to monkey 1!
# Monkey 0 is inspecting item with worry level 14
#   Monkey 0 throws item 88 to monkey 3!
# Monkey 0 is inspecting item with worry level 17
#   Monkey 0 throws item 107 to monkey 3!
# Monkey 1 is inspecting item with worry level 481
#   Monkey 1 throws item 162 to monkey 0!
# Monkey 1 is inspecting item with worry level 176
#   Monkey 1 throws item 60 to monkey 0!
# Monkey 1 is inspecting item with worry level 93
#   Monkey 1 throws item 33 to monkey 0!
# Monkey 1 is inspecting item with worry level 389
#   Monkey 1 throws item 131 to monkey 0!
# Monkey 1 is inspecting item with worry level 20
#   Monkey 1 throws item 8 to monkey 0!
# Monkey 1 is inspecting item with worry level 43
#   Monkey 1 throws item 16 to monkey 0!
# Monkey 1 is inspecting item with worry level 55
#   Monkey 1 throws item 20 to monkey 0!
# Monkey 1 is inspecting item with worry level 216
#   Monkey 1 throws item 74 to monkey 0!
# Monkey 3 is inspecting item with worry level 88
#   Monkey 3 throws item 30 to monkey 1!
# Monkey 3 is inspecting item with worry level 107
#   Monkey 3 throws item 36 to monkey 1!
# Monkey 0 is inspecting item with worry level 162
#   Monkey 0 throws item 1026 to monkey 3!
# Monkey 0 is inspecting item with worry level 60
#   Monkey 0 throws item 380 to monkey 3!
# Monkey 0 is inspecting item with worry level 33
#   Monkey 0 throws item 209 to monkey 3!
# Monkey 0 is inspecting item with worry level 131
#   Monkey 0 throws item 829 to monkey 3!
# Monkey 0 is inspecting item with worry level 8
#   Monkey 0 throws item 50 to monkey 3!
# Monkey 0 is inspecting item with worry level 16
#   Monkey 0 throws item 101 to monkey 3!
# Monkey 0 is inspecting item with worry level 20
#   Monkey 0 throws item 126 to monkey 3!
# Monkey 0 is inspecting item with worry level 74
#   Monkey 0 throws item 468 to monkey 3!
# Monkey 1 is inspecting item with worry level 30
#   Monkey 1 throws item 12 to monkey 0!
# Monkey 1 is inspecting item with worry level 36
#   Monkey 1 throws item 14 to monkey 0!
# Monkey 3 is inspecting item with worry level 1026
#   Monkey 3 throws item 343 to monkey 1!
# Monkey 3 is inspecting item with worry level 380
#   Monkey 3 throws item 127 to monkey 1!
# Monkey 3 is inspecting item with worry level 209
#   Monkey 3 throws item 70 to monkey 1!
# Monkey 3 is inspecting item with worry level 829
#   Monkey 3 throws item 277 to monkey 1!
# Monkey 3 is inspecting item with worry level 50
#   Monkey 3 throws item 17 to monkey 0!
# Monkey 3 is inspecting item with worry level 101
#   Monkey 3 throws item 34 to monkey 0!
# Monkey 3 is inspecting item with worry level 126
#   Monkey 3 throws item 43 to monkey 1!
# Monkey 3 is inspecting item with worry level 468
#   Monkey 3 throws item 157 to monkey 1!
# Monkey 0 is inspecting item with worry level 12
#   Monkey 0 throws item 76 to monkey 3!
# Monkey 0 is inspecting item with worry level 14
#   Monkey 0 throws item 88 to monkey 3!
# Monkey 0 is inspecting item with worry level 17
#   Monkey 0 throws item 107 to monkey 3!
# Monkey 0 is inspecting item with worry level 34
#   Monkey 0 throws item 215 to monkey 3!
# Monkey 1 is inspecting item with worry level 343
#   Monkey 1 throws item 116 to monkey 0!
# Monkey 1 is inspecting item with worry level 127
#   Monkey 1 throws item 44 to monkey 0!
# Monkey 1 is inspecting item with worry level 70
#   Monkey 1 throws item 25 to monkey 0!
# Monkey 1 is inspecting item with worry level 277
#   Monkey 1 throws item 94 to monkey 0!
# Monkey 1 is inspecting item with worry level 43
#   Monkey 1 throws item 16 to monkey 0!
# Monkey 1 is inspecting item with worry level 157
#   Monkey 1 throws item 54 to monkey 0!
# Monkey 3 is inspecting item with worry level 76
#   Monkey 3 throws item 26 to monkey 1!
# Monkey 3 is inspecting item with worry level 88
#   Monkey 3 throws item 30 to monkey 1!
# Monkey 3 is inspecting item with worry level 107
#   Monkey 3 throws item 36 to monkey 1!
# Monkey 3 is inspecting item with worry level 215
#   Monkey 3 throws item 72 to monkey 1!
# Monkey 0 is inspecting item with worry level 116
#   Monkey 0 throws item 734 to monkey 3!
# Monkey 0 is inspecting item with worry level 44
#   Monkey 0 throws item 278 to monkey 3!
# Monkey 0 is inspecting item with worry level 25
#   Monkey 0 throws item 158 to monkey 3!
# Monkey 0 is inspecting item with worry level 94
#   Monkey 0 throws item 595 to monkey 3!
# Monkey 0 is inspecting item with worry level 16
#   Monkey 0 throws item 101 to monkey 3!
# Monkey 0 is inspecting item with worry level 54
#   Monkey 0 throws item 342 to monkey 3!
# Monkey 1 is inspecting item with worry level 26
#   Monkey 1 throws item 10 to monkey 0!
# Monkey 1 is inspecting item with worry level 30
#   Monkey 1 throws item 12 to monkey 0!
# Monkey 1 is inspecting item with worry level 36
#   Monkey 1 throws item 14 to monkey 0!
# Monkey 1 is inspecting item with worry level 72
#   Monkey 1 throws item 26 to monkey 0!
# Monkey 3 is inspecting item with worry level 734
#   Monkey 3 throws item 245 to monkey 1!
# Monkey 3 is inspecting item with worry level 278
#   Monkey 3 throws item 93 to monkey 1!
# Monkey 3 is inspecting item with worry level 158
#   Monkey 3 throws item 53 to monkey 1!
# Monkey 3 is inspecting item with worry level 595
#   Monkey 3 throws item 199 to monkey 1!
# Monkey 3 is inspecting item with worry level 101
#   Monkey 3 throws item 34 to monkey 0!
# Monkey 3 is inspecting item with worry level 342
#   Monkey 3 throws item 115 to monkey 1!
# The most active monkey is  Monkey 3 Has items [], and then monkey Monkey 0 Has items [10, 12, 14, 26, 34]

# %%
calculate_monkey_business(real_monkeys)
# Out:
# Adjust monkey business by 9699690
# Ran 0 rounds
# The most active monkey is  Monkey 7 Has items [], and then monkey Monkey 4 Has items []
# 119715

# %% [markdown]
# ## Part 2

# %%
example_monkeys = parse(example_data)
assert calculate_monkey_business(example_monkeys, num_rounds=10000, divide_worry_level=False) == 2713310158

real_monkeys = parse(raw_data)
calculate_monkey_business(real_monkeys, num_rounds = 10000, divide_worry_level = False)
# Out:
# Adjust monkey business by 96577
# Ran 0 rounds
# Ran 1000 rounds
# Ran 2000 rounds
# Ran 3000 rounds
# Ran 4000 rounds
# Ran 5000 rounds
# Ran 6000 rounds
# Ran 7000 rounds
# Ran 8000 rounds
# Ran 9000 rounds
# The most active monkey is  Monkey 0 Has items [63602, 56040, 11941, 10573, 61607], and then monkey Monkey 3 Has items []
# Adjust monkey business by 9699690
# Ran 0 rounds
# Ran 1000 rounds
# Ran 2000 rounds
# Ran 3000 rounds
# Ran 4000 rounds
# Ran 5000 rounds
# Ran 6000 rounds
# Ran 7000 rounds
# Ran 8000 rounds
# Ran 9000 rounds
# The most active monkey is  Monkey 4 Has items [], and then monkey Monkey 2 Has items [6438397, 919244, 8576894, 8066384, 2523704, 8066384, 919244, 919244, 6170204, 2543000, 355100, 2543000, 9325490, 6627080, 6627080, 1157330]
# 18085004878
